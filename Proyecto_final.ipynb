# %% [markdown]
# <a href="https://colab.research.google.com/github/bankros/OPTIMIZACI-N-1/blob/main/Proyecto_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problema
# Este problema consta de lo siguiente: trataremos de ajustar las rutas más optimas donde pueda pasar el camión de basura en el municipio de Pradera, pero para poder hacer eso, tambien hay que realizar algunos ajuste, asi que arranquemos en si con el enuciado del problema.
#
# El municipio de pradera consta con un solo camión de basura y 8 trabajadores en recolección de basura contando con el chofer del camión, y entre ellos varian los dias que le toca recolectar o limpiar calles, inician la jornada laboral a las 6 de la mañana y la finalizan a las 4 pm, el camión cada![zonas de recolección.jpg](data:image/jpeg;base64,...)a dia pasa por unas rutas ya estipuladas(ver grafico) con un horario fijado, a lo cual tiene que terminar su ruta a mas tardar a las 3pm, para poder llevar la basura al vertedero que queda por gorgona.
#
#  Veamos el mapa del municipio, las zonas de recolección y rutas tomadas.
#  ![croquis de pradera.png](data:image/png;base64,...)

# %% [markdown]
# Ademas tambien pasa que en un solo día limpia una zona y al otro día la parte restante(ver grafica), es decir el lunes comienza en la zona morada  y martes zona verde, y así sucesivamente lo hace toda la semana.
# ![formatado de recoleccion de basura.png](data:image/png;base64,...)

# %% [markdown]
# # Planteamiento del ejercicio

# %%
# !pip install PuLP
# Out:
# ...
#      |████████████████████████████████| 14.2 MB 4.1 MB/s
# ...

# %% [markdown]
# # Importación de paquetes

# %%
import pulp
